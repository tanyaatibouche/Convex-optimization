# %%
import numpy as np


def gradient_descent(grad_fn, x0, lr=0.01, n_iters=1000, tol=1e-8):
    x = np.array(x0, dtype=float)
    history = [x.copy()]

    for _ in range(n_iters):
        grad = np.array(grad_fn(x), dtype=float)
        x_next = x - lr * grad
        history.append(x_next.copy())

        if np.linalg.norm(x_next - x) < tol:
            x = x_next
            break

        x = x_next

    return x, np.array(history)

# %%
import numpy as np


def sgd(grad_sample_fn, x0, n_samples, lr=0.01, n_epochs=10, shuffle=True, seed=None):
    rng = np.random.default_rng(seed)
    x = np.array(x0, dtype=float)
    history = [x.copy()]

    for _ in range(n_epochs):
        indices = np.arange(n_samples)
        if shuffle:
            rng.shuffle(indices)

        for i in indices:
            grad = np.array(grad_sample_fn(x, i), dtype=float)
            x = x - lr * grad
            history.append(x.copy())

    return x, np.array(history)

# %%
import numpy as np


def batch_gradient_descent(grad_batch_fn, x0, lr=0.01, n_iters=1000, tol=1e-8):
    x = np.array(x0, dtype=float)
    history = [x.copy()]

    for _ in range(n_iters):
        grad = np.array(grad_batch_fn(x), dtype=float)
        x_next = x - lr * grad
        history.append(x_next.copy())

        if np.linalg.norm(x_next - x) < tol:
            x = x_next
            break

        x = x_next

    return x, np.array(history)

# %%
import numpy as np


def adam(grad_fn, x0, lr=0.001, beta1=0.9, beta2=0.999, eps=1e-8, n_iters=1000):
    x = np.array(x0, dtype=float)
    m = np.zeros_like(x)
    v = np.zeros_like(x)
    history = [x.copy()]

    for t in range(1, n_iters + 1):
        g = np.array(grad_fn(x), dtype=float)
        m = beta1 * m + (1 - beta1) * g
        v = beta2 * v + (1 - beta2) * (g ** 2)

        m_hat = m / (1 - beta1 ** t)
        v_hat = v / (1 - beta2 ** t)

        x = x - lr * m_hat / (np.sqrt(v_hat) + eps)
        history.append(x.copy())

    return x, np.array(history)
